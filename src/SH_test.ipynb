# %%
# SH test
include("MDBM__types.jl")

function f(a,b)
    a^2.0+b^2.0-2.0
end
function c(a,b)
    a-b
end

ax1=Axis([-5,-2.5,0,2.5,5],"a")
ax2=Axis(-3:3.0,"b")

mymdbm=MDBM_Problem(f,[ax1,ax2],constraint=c)
# mymdbm=MDBM_Problem(f,[ax1,ax2])

interpolate!(mymdbm,interpolationorder=1)
for k=1:4
refine!(mymdbm)
interpolate!(mymdbm,interpolationorder=1)
end

using Plots
gr()

#evaluated points
a_eval=[x.callargs[1] for x in mymdbm.fc.fvalarg]
b_eval=[x.callargs[2] for x in mymdbm.fc.fvalarg]
scatter(a_eval,b_eval)

#solution points
a_sol,b_sol=getinterpolatedpoint(mymdbm)
scatter!(a_sol,b_sol,xlabel = ax1.name,ylabel = ax2.name,size = (600, 600))

# %%
# SH test
include("MDBM__types.jl")

function f(a,b)
    a^2.0+b^2.0-2.0
end
function c(a,b)
    a-b
end

ax1=Axis([-5,-2.5,0,2.5,5],"a")
ax2=Axis(-3:3.0,"b")

mymdbm=MDBM_Problem(f,[ax1,ax2],constraint=c)
# mymdbm=MDBM_Problem(f,[ax1,ax2])

interpolate!(mymdbm,interpolationorder=0)
for k=1:4
refine!(mymdbm)
interpolate!(mymdbm,interpolationorder=0)
end

using Plots
gr()

#evaluated points
a_eval=[x.callargs[1] for x in mymdbm.fc.fvalarg]
b_eval=[x.callargs[2] for x in mymdbm.fc.fvalarg]
scatter(a_eval,b_eval)

#solution points
a_sol,b_sol=getinterpolatedpoint(mymdbm)
scatter!(a_sol,b_sol,xlabel = ax1.name,ylabel = ax2.name,size = (600, 600))
